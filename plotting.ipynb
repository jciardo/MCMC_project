# %%
from utils.plot_utils import plot_min_energy_vs_N

# %%
#!have commented in the main not to plot ; too costly

min_energy_by_N = { #! for now dict for 10 runs each
    3: 26,
    4: 46,
    5: 68,
    6: 94,
    7: 110,
    8: 112,
    9: 114,
    10: 82,
    11: 0,
    12: 268,
    13: 326,
    14: 372,
    15: 436,
    16: 498,
    17: 570,
    18: 648,
}
#! with 10 with seed .. and 10 runs we get 82 as lowest value ;

plot_min_energy_vs_N(
    min_energy_by_N,
    save_path="plots/min_energy_vs_N.png",
)
